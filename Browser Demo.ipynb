# %%
import kg_browser as kg

# %%
b = kg.KGBrowser()

# %% [markdown]
# Retrieve all the nodes in the Training Concept Graph:

# %%
b.all_nodes
# Out:
# ['C4071858',
#  'C1517874',
#  'C0032015',
#  'C1332749',
#  'C4281806',
#  'C0227211',
#  'C1854704',
#  'C0206343',
#  'C0023089',
#  'C0868658',
#  'C1444647',
#  'C0033109',
#  'C1366462',
#  'C0489458',
#  'C0041450',
#  'C0563276',
#  'C0030490',
#  'C0865783',
#  'C4281563',
#  'C0997923',
#  'C1335965',
#  'C1537486',
#  'C0871627',
#  'C3854530',
#  'C4505265',
#  'C0282514',
#  'C0021760',
#  'C0396473',
#  'C0897751',
#  'C4740292',
#  'C0032086',
#  'C0553698',
#  'C0065264',
#  'C0014894',
#  'C0873033',
#  'C1057134',
#  'C0216194',
#  'C0281839',
#  'C0315045',
#  'C0179874',
#  'C2984839',
#  'C0330783',
#  'C1299503',
#  'C0398159',
#  'C0026809',
#  'C0013938',
#  'C0193317',
#  'C0205117',
#  'C0028792',
#  'C0193101',
#  'C1522449',
#  'C2266079',
#  'C2934781',
#  'C0038835',
#  'C0175693',
#  'C2331620',
#  'C0729349',
#  'C0200008',
#  'C0018206',
#  'C0519066',
#  'C1268717',
#  'C4235027',
#  'C0444094',
#  'C0336548',
#  'C1427960',
#  'C0268009',
# ...

# %% [markdown]
# Retrieve (not calculate) the shortest path length between two nodes:

# %%
b.retrieve_spl('C4071858', 'C1517874')
# Out:
# 4

# %% [markdown]
# Retrieve (not calculate) our estimated normalized betweenness centrality between two nodes:

# %%
b.retrieve_betweenness('C1517874')
# Out:
# 2.723886672857484e-07

# %% [markdown]
# Obtain the probability of an edge between two nodes, using one of the three models we provide:

# %%
b.link_prob('C0865783', 'C0877248', method = "geodesic")
# Out:
# 0.7426130431792423

# %%
b.link_prob('C0865783', 'C0877248', method = "embeddings_lr")
# Out:
# 0.7301978552367975

# %%
b.link_prob('C0865783', 'C0877248', method = "embeddings_mlp")
# Out:
# 0.9999998794888788
